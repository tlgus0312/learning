# %% [markdown]
# # 1. 네이버 뉴스 Crawling with Naver Open API
# - 네이버 개발자 가입 : 서비스 API > 검색 > [오픈 API 이용 신청]
# - 검색 API 사용 신청 : Products > 검색 > [오픈 API 이용 신청]
#
# https://developers.naver.com/main/
#
# ##데이터를 수집하는 방법에서 crawing과 scrapping
# ## crawing api가 있는것, scrapping은 html로 사용 -> BeautifulSoup

# %%
# 네이버 검색 API 예제 -  블로그 검색 예제를 뉴스 검색 예제로 수정하여 실행
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "DrQl52mvUfRfnzIEBXKW"
client_secret = "tyQAVEuvtx"
#한글 검색어 안전하게 변환 
encText = urllib.parse.quote("광명북고")
#url+query 생성
url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과

# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
#request message 구성 
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
#request-> response 받아오기
response = urllib.request.urlopen(request)
#받아온 결과가 정상인지 확인
rescode = response.getcode()
if(rescode==200):
    #정상이면, 데이터 읽어오기
    response_body = response.read()
    #한글이 있으면 , UTF-8로 변환 
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 19 Mar 2025 18:21:29 +0900",
# 	"total":1535,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>광명북고<\/b> 조형우-이형우, 2025 네덜란드주니어오픈대회 남자복식 금메달",
# 			"originallink":"https:\/\/www.kgnews.co.kr\/news\/article.html?no=833662",
# 			"link":"https:\/\/www.kgnews.co.kr\/news\/article.html?no=833662",
# 			"description":"결승서 중국에 세트 스코어 2-1 승 <b>광명북고<\/b> 조형우, 이형우가 2025 네덜란드주니어오픈배드민턴선수권대회 남자 복식에서 나란히 정상에 올랐다. 이형우는 지난 2일 네덜란드 하를렘 배드민턴홀 데지로홀에서 열린... ",
# 			"pubDate":"Wed, 05 Mar 2025 17:28:00 +0900"
# 		},
# 		{
# 			"title":"<b>광명북고<\/b> '쌍' 형우 2025 네덜란드·독일 주니어 배드민턴선수권대회 출...",
# 			"originallink":"https:\/\/www.incheonilbo.com\/news\/articleView.html?idxno=1280112",
# 			"link":"https:\/\/www.incheonilbo.com\/news\/articleView.html?idxno=1280112",
# 			"description":"\/사진제공=대한배드민턴협회 이형우와 조형우(이상 <b>광명북고<\/b>)가 태극마크를 달고 2025 네덜란드(2.26~3.2) 및 독일(3.5~3.9) 주니어 배드민턴선수권대회에 출전한다. 먼저 이형우는 2024년 각종 국제대회에서 맹활약을... ",
# 			"pubDate":"Tue, 25 Feb 2025 11:16:00 +0900"
# 		},
# 		{
# 			"title":"요넥스, 이용대 BWF 명예의 전당 헌액 축하 행사 및 신인선수 입단식 개...",
# 			"originallink":"https:\/\/sports.donga.com\/sports\/article\/all\/20250123\/130917905\/1",
# 			"link":"https:\/\/m.sports.naver.com\/general\/article\/382\/0001174768",
# 			"description":"올해 <b>광명북고<\/b>를 졸업한 이선진은 2023년 태국주니어국제배드민턴선수권대회 남자 단·복식을 모두 제패했고, 지난해에도 전국체전과 전국연맹종별배드민턴선수권대회 남자복식을 모두 석권한 유망주다. 요넥스는 장신... ",
# 			"pubDate":"Thu, 23 Jan 2025 00:38:00 +0900"
# 		},
# 		{
# 			"title":"서울보다 낫네, 철산",
# 			"originallink":"https:\/\/magazine.hankyung.com\/money\/article\/202412094282c",
# 			"link":"https:\/\/magazine.hankyung.com\/money\/article\/202412094282c",
# 			"description":"철산중과 진성고를 비롯해 <b>광명북고<\/b>, 소하고 등 우수한 학교들이 다수 포진해 있습니다. 학원가는 철산역 주변에 일부 형성됐지만 대규모는 아닙니다. 도시의 전반적인 학구열과 교육열이 높은 편입니다. 또 서울... ",
# 			"pubDate":"Tue, 07 Jan 2025 16:24:00 +0900"
# 		},
# 		{
# 			"title":"2025년 한국 배드민턴 국가대표 선수 남자 19명 여자 19명 선발 완료",
# 			"originallink":"https:\/\/www.thefairnews.co.kr\/news\/articleView.html?idxno=38616",
# 			"link":"https:\/\/www.thefairnews.co.kr\/news\/articleView.html?idxno=38616",
# 			"description":"남자복식은 서승재(삼성생명), 김원호(삼성생명), 강민혁(삼성생명), 기동주(인천국제공항), 나성승(김천시청), 진용(요넥스), 김재현(요넥스), 이종민(<b>광명북고<\/b>), 노진성(요넥스), 박승민(경희대), 이상원(충주시청) 등... ",
# 			"pubDate":"Sun, 29 Dec 2024 10:20:00 +0900"
# 		},
# 		{
# 			"title":"한국 꿈나무들 2024 BATYONEX Pathumthani 태국주니어배드민턴대회 휩쓸었...",
# 			"originallink":"https:\/\/www.incheonilbo.com\/news\/articleView.html?idxno=1274015",
# 			"link":"https:\/\/www.incheonilbo.com\/news\/articleView.html?idxno=1274015",
# 			"description":"이형우-천혜인(<b>광명북고<\/b>2년\/전주성심여고2년)이 각각 금메달의 주인공이 됐다. 이 중 이형우-천혜인은 지난달 열린 2024 YONEX-SINGHA 태국주니어배드민턴선수권대회 혼합복식(U-19) 우승에 이어 이번 대회에서도... ",
# 			"pubDate":"Mon, 16 Dec 2024 11:16:00 +0900"
# 		},
# 		{
# 			"title":"[단독] [2024진학률] 경기 386개 일반고 54.8% '상승'.. 태광 능동 효양 ...",
# 			"originallink":"http:\/\/www.veritas-a.com\/news\/articleView.html?idxno=532700",
# 			"link":"http:\/\/www.veritas-a.com\/news\/articleView.html?idxno=532700",
# 			"description":"37%(115명\/248명), <b>광명북고<\/b>(광명) 46.36%(121명\/261명), 도당고(부천) 46.34%(95명\/205명), 신장고(하남) 45.93%(96명\/209명), 풍생고(성남) 45.81%(93명\/203명), 시흥매화고(시흥) 45.74%(86명\/188명), 부천고(부천) 45.71... ",
# 			"pubDate":"Mon, 02 Dec 2024 16:56:00 +0900"
# 		},
# 		{
# 			"title":"전대사대부고 현수민·김민승, 태국주니어배드민턴선수권 남복 준우승",
# 			"originallink":"http:\/\/www.jnilbo.com\/75484645850",
# 			"link":"http:\/\/www.jnilbo.com\/75484645850",
# 			"description":"24일 광주시배드민턴협회에 따르면 전대사대부고 현수민과 김민승은 지난 12~17일 태국 방콕에서 열린 이번 대회 남자복식 결승전에서 한국의 조형우-이형우(이상 <b>광명북고<\/b>) 조에 1-2로 석패하며 준우승에 머물렀다.... ",
# 			"pubDate":"Sun, 24 Nov 2024 13:18:00 +0900"
# 		},
# 		{
# 			"title":"광주사대부고, 태국주니어배드민턴선수권 값진 준우승",
# 			"originallink":"http:\/\/www.jndn.com\/article.php?aid=1732180497398993010",
# 			"link":"http:\/\/www.jndn.com\/article.php?aid=1732180497398993010",
# 			"description":"현수민-김민승조로 이뤄진 광주사대부고는 지난 17일 태국 방콕에서 끝난 이번 대회에서 한국 조형우-이형우(이상 <b>광명북고<\/b>)조에 1-2로 패배, 2위에 올랐다. 한국 주니어배드민턴 대표팀은 U-19 남·여 각 10명씩... ",
# 			"pubDate":"Thu, 21 Nov 2024 18:18:00 +0900"
# 		},
# 		{
# 			"title":"제35회 태인체육장학금 수여식... 道 체육인 유망주 16명 수상",
# 			"originallink":"https:\/\/www.kgnews.co.kr\/news\/article.html?no=818365",
# 			"link":"https:\/\/www.kgnews.co.kr\/news\/article.html?no=818365",
# 			"description":"이선진(<b>광명북고<\/b>), ▲ 보디빌딩= 배진영(일동고), ▲ 볼링= 배정훈(수원 곡정고), ▲ 쇼트트랙= 강민지(인천예일고), ▲ 산악= 이학진(인천예일고), ▲ 웨이크보드= 김서후(인천신현고), ▲ 컬링= 박건우(의정부고), ▲ 택견... ",
# 			"pubDate":"Wed, 20 Nov 2024 17:20:00 +0900"
# 		}
# 	]
# }

# %% [markdown]
# # 2. urllib : URL 작업용 패키지 (built-in)
# * import urllib
# * HTTP, FTP, SMTP 등과 같은 프로토콜을 사용하여 URL을 열고 읽고 쓰는 기능 제공
#
# * https://ctkim.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-urllib-%EB%AA%A8%EB%93%88
#    - urllib.request : 다양한 방식으로 URL을 열고 데이터를 가져오는 기능 제공
#    - urllib.response : urllib가 사용하는 응답 클래스
#    - urllib.parse : URL 파싱, 인코딩, 디코딩
#    - urllib.robotparser : robots.txt 파일의 parsing
#
#
# ## 2-1. urllib으로 Open API 사용하기
#   - 특수문자 및 비ASCII코드를 url에 사용할 수 있도록 변경 : *string* = **urllib.parse.quote**(*string*)
#     유니코드가 넘어감
#   - 요청 메시지 생성
#     - Request 객체 생성 : *request_object* = **urllib.request.Request**(*url*)
#     - Request 객체 Header에 API 사용을 위한 정보 추가 : *request_object*.**add_header(*key*, *val*)
#   - API 요청 및 결과 받기
#     - Request 객체로 url 열고 HTTPResponse 객체 받기 : *Response* = **urllib.request.urlopen**(*Request*)
#     - urlopen 결과 상태 정보 얻기 : *Response*.**getcode()** (**status**)
#     - Response 객체에서 요청 결과 얻기 : *Response*.**read()**
#     - 결과에 한글이 표함된 경우 UTF-8로 디코팅 : *string*.**decode**('utf-8')

# %% [markdown]
# ## Naver 검색 API 동작 방식
#    - start부터 display 수만큼 검색 결과를 json으로 가져옴
#    - 검색 결과는 json의 'items'에 들어 있음
#    - 검색 결과 수는 'display'에 들어 있음

# %% [markdown]
# #예시
# # 네이버 검색 API 예제 기반으로 네이버 검색 API 동작 방식 확인 (검색 결과 모두 받기)
# # rescode가 200인 동안 start를 증가시켜서 계속 검색 (테스트를 위해 start는 25이하로 제한)
# import os
# import sys
# import urllib.request
# client_id = "DrQl52mvUfRfnzIEBXKW"
# client_secret = "tyQAVEuvtx"
# #한글 검색어 안전하게 변환
# encText = urllib.parse.quote("인공지능")
# #url+query 생성
# url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과
# start = 1
# display = 10
# rescode=200
#
# while rescode ==200 and start <30:
#     # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
#     #request message 구성
#     new_url =url+f"&start={start}&display={display}"
#     request = urllib.request.Request(new_url)
#     request.add_header("X-Naver-Client-Id",client_id)
#     request.add_header("X-Naver-Client-Secret",client_secret)
#     #request-> response 받아오기
#     response = urllib.request.urlopen(request)
#     #받아온 결과가 정상인지 확인
#     rescode = response.getcode()
#     if(rescode==200):
#         #정상이면, 데이터 읽어오기
#         response_body = response.read()
#         #한글이 있으면 , UTF-8로 변환
#         print(response_body.decode('utf-8'))
#     else:
#         print("Error Code:" + rescode)
#
#     start += display

# %% [markdown]
# # 3. json : JSON 데이터 파싱,생성 (built-in)
# * import json
# * JSON 문자열을 파이썬 객체로 변환 : *pyObject* = **json.loads**(*jsonString*)
# * 파이썬 객체를 JSON 문자열로 변환 : *jsonString* = **json.dumps**(*pyObject*)
#    - ensure_ascii=True : 한글일때는 False로 변경하기
#    - indent=None : 가독성을 높이기 위해 숫자 지정하기
# * JSON 파일을 파이썬 객체로 로딩 : *pyObject* = **json.load**()
# * 파이썬 객체를 JSON 파일에 저장 : **json.dump**(*pyObject*, *fileObject*)
#
# https://docs.python.org/3/library/json.html

# %% [markdown]
# # [ 프로그램 Workflow ]
# 1. 네이버 뉴스 API로 Crawling : **searchNaverNews()** -> 파이썬 json 데이터
#    1. url 구성하기
#    1. url 접속과 검색 요청하기
#    1. url 요청결과를 응답 json으로 받기 (json.loads)
# 1. 응답데이터를 리스트에 저장 : **setNewSearchResult** -> List
# 1. 응답데이터가 없을 때까지 반복
#    1. 파이썬 예외처리 : try + except + else + finally
# 1. 리스트를 CSV 파일로 저장 : **saveSearchResult** (pd.to_csv)

# %%
import urllib.request
import json

def searchNaverNews(keyword, start, display):

    client_id = "DrQl52mvUfRfnzIEBXKW"
    client_secret = "tyQAVEuvtx"
    #한글 검색어 안전하게 변환 
    encText = urllib.parse.quote(keyword)
    #url+query 생성
    url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과
    new_url = url + f"&start={start}&display={display}"
    request = urllib.request.Request(new_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    resultJSON=None
    try:
            #request-> response 받아오기
        response = urllib.request.urlopen(request)
            #받아온 결과가 정상인지 확인
        rescode = response.getcode()
        if(rescode==200):
                #정상이면, 데이터 읽어오기
            response_body = response.read()
                #한글이 있으면 , UTF-8로 변환 
            resultJSON = json.loads(response_body.decode('utf-8'))
        else:
            print("error")

    except Exception as e:
            print(e)
            print(f"Error:{new_url}")
    return resultJSON

# %%
#응답데이터를 리스트에 저장 (검색 결과는 json의 'items'에 들어 있음)
def setNewsSearchResult(resultAll, resultJSON):
    for result in resultJSON["items"]:
        resultAll.append(result)

# %%
# JSON의 list를 dataframe으로 변환하여 csv 파일로 저장
def saveSearchResult_CSV(json_list, filename):
    import pandas as pd 
    data_df = pd.DataFrame(json_list)
    data_df.to_csv(filename)
    print(f"{filename} SAVED")

# %%
# 검색어 입력
keyword =input("검색어:").strip()
#keyword ="인공지능"

# API 호출 결과 전송된 JSON이 없거나, 전송된 JSON에 검색 결과가 없을 때까지
# 검색 결과를 JSON의 list로 저장 후 검색 API 추가 호출


# 검색 결과를 저장할 list 초기화
resultAll = []

# 첫 검색 API 호출
start = 1
display = 10
resultJSON = searchNaverNews(keyword,start,display)

while (resultJSON != None) and (resultJSON['display'] > 0):
     # 응답데이터 정리하여 리스트 저장
    setNewsSearchResult(resultAll, resultJSON)
 
    # 다음 검색 API 호출을 위한 파라미터 조정
    start += display

   
    resultJSON = searchNaverNews(keyword, start,display)
     # API 호출 성공 여부 출력
    if resultJSON != None:
        print(f"{keyword}[{start}]:AllOk")
    else:
        print(f"{keyword}[{start}] : Error")



# 리스트를 csv 파일로 저장
filename=f"../data/{keyword}_naver_news.csv"
saveSearchResult_CSV(resultAll, filename)
# Out:
# 검색어: 벚꽃
# 벚꽃[11]:AllOk
# 벚꽃[21]:AllOk
# 벚꽃[31]:AllOk
# 벚꽃[41]:AllOk
# 벚꽃[51]:AllOk
# 벚꽃[61]:AllOk
# 벚꽃[71]:AllOk
# 벚꽃[81]:AllOk
# 벚꽃[91]:AllOk
# 벚꽃[101]:AllOk
# 벚꽃[111]:AllOk
# 벚꽃[121]:AllOk
# 벚꽃[131]:AllOk
# 벚꽃[141]:AllOk
# 벚꽃[151]:AllOk
# 벚꽃[161]:AllOk
# 벚꽃[171]:AllOk
# 벚꽃[181]:AllOk
# 벚꽃[191]:AllOk
# 벚꽃[201]:AllOk
# 벚꽃[211]:AllOk
# 벚꽃[221]:AllOk
# 벚꽃[231]:AllOk
# 벚꽃[241]:AllOk
# 벚꽃[251]:AllOk
# 벚꽃[261]:AllOk
# 벚꽃[271]:AllOk
# 벚꽃[281]:AllOk
# 벚꽃[291]:AllOk
# 벚꽃[301]:AllOk
# 벚꽃[311]:AllOk
# 벚꽃[321]:AllOk
# 벚꽃[331]:AllOk
# 벚꽃[341]:AllOk
# 벚꽃[351]:AllOk
# 벚꽃[361]:AllOk
# 벚꽃[371]:AllOk
# 벚꽃[381]:AllOk
# 벚꽃[391]:AllOk
# 벚꽃[401]:AllOk
# 벚꽃[411]:AllOk
# 벚꽃[421]:AllOk
# 벚꽃[431]:AllOk
# 벚꽃[441]:AllOk
# 벚꽃[451]:AllOk
# 벚꽃[461]:AllOk
# 벚꽃[471]:AllOk
# 벚꽃[481]:AllOk
# 벚꽃[491]:AllOk
# 벚꽃[501]:AllOk
# 벚꽃[511]:AllOk
# 벚꽃[521]:AllOk
# 벚꽃[531]:AllOk
# 벚꽃[541]:AllOk
# 벚꽃[551]:AllOk
# 벚꽃[561]:AllOk
# 벚꽃[571]:AllOk
# 벚꽃[581]:AllOk
# 벚꽃[591]:AllOk
# 벚꽃[601]:AllOk
# 벚꽃[611]:AllOk
# 벚꽃[621]:AllOk
# 벚꽃[631]:AllOk
# 벚꽃[641]:AllOk
# 벚꽃[651]:AllOk
# 벚꽃[661]:AllOk
# 벚꽃[671]:AllOk
# 벚꽃[681]:AllOk
# 벚꽃[691]:AllOk
# 벚꽃[701]:AllOk
# 벚꽃[711]:AllOk
# 벚꽃[721]:AllOk
# 벚꽃[731]:AllOk
# 벚꽃[741]:AllOk
# 벚꽃[751]:AllOk
# 벚꽃[761]:AllOk
# 벚꽃[771]:AllOk
# 벚꽃[781]:AllOk
# 벚꽃[791]:AllOk
# 벚꽃[801]:AllOk
# 벚꽃[811]:AllOk
# 벚꽃[821]:AllOk
# 벚꽃[831]:AllOk
# 벚꽃[841]:AllOk
# 벚꽃[851]:AllOk
# 벚꽃[861]:AllOk
# 벚꽃[871]:AllOk
# 벚꽃[881]:AllOk
# 벚꽃[891]:AllOk
# 벚꽃[901]:AllOk
# 벚꽃[911]:AllOk
# 벚꽃[921]:AllOk
# 벚꽃[931]:AllOk
# 벚꽃[941]:AllOk
# 벚꽃[951]:AllOk
# 벚꽃[961]:AllOk
# 벚꽃[971]:AllOk
# 벚꽃[981]:AllOk
# 벚꽃[991]:AllOk
# HTTP Error 400: Bad Request
# Error:https://openapi.naver.com/v1/search/news?query=%EB%B2%9A%EA%BD%83&start=1001&display=10
# 벚꽃[1001] : Error
# ../data/벚꽃_naver_news.csv SAVED

# %%
# 저장한 파일을 dataframe으로 loading 해보기
import pandas as pd 
data_df = pd.read_csv(filename, index_col=0)
data_df
# Out:
#                                        title  \
# 0                     흩날리는 <b>벚꽃</b> 속 걸어볼까요
# 1             보성군, 29일 왕벚나무터널서 '<b>벚꽃</b>축제'
# 2              <b>벚꽃</b>과 함께 즐기는 국내 최고의 골프장들
# 3    올해도 해외여행객 역대급 전망… 1∼2월 국제선 여객 전년 대비 9%↑
# 4            문화예술 교육 확장… 임실군, 꿈의 무용단 공모사업 선정
# ..                                       ...
# 995                       광양시, 3월 읍면동장 회의 개최
# 996              청주시, '전국 최초' 다회용기 공공세척센터 개소
# 997           고창군, 매주 토요일 주요 관광지 '시티투어버스' 운영
# 998            '청주는 예술이쥬' 제22회 청주예술제 28일 팡파르
# 999   순천시, 지역 이야기를 담은 '<b>벚꽃</b> 스냅사진 투어' 운영
#
#                                           originallink  \
# 0    https://www.jemin.com/news/articleView.html?id...
# 1    http://www.newskr.kr/news/articleView.html?idx...
# 2    https://www.golfjournal.co.kr/news/articleView...
# 3    https://www.sisaweek.com/news/articleView.html...
# 4    https://www.newscj.com/news/articleView.html?i...
# ..                                                 ...
# 995  http://www.bzeronews.com/news/articleView.html...
# 996  http://www.bzeronews.com/news/articleView.html...
# 997         https://www.news1.kr/local/jeonbuk/5721667
# 998  https://www.jbnews.com/news/articleView.html?i...
# 999  http://www.bzeronews.com/news/articleView.html...
#
#                                                   link  \
# 0    https://www.jemin.com/news/articleView.html?id...
# 1    http://www.newskr.kr/news/articleView.html?idx...
# 2    https://www.golfjournal.co.kr/news/articleView...
# 3    https://www.sisaweek.com/news/articleView.html...
# 4    https://www.newscj.com/news/articleView.html?i...
# ..                                                 ...
# 995  http://www.bzeronews.com/news/articleView.html...
# 996  http://www.bzeronews.com/news/articleView.html...
# 997  https://n.news.naver.com/mnews/article/421/000...
# 998  https://www.jbnews.com/news/articleView.html?i...
# 999  http://www.bzeronews.com/news/articleView.html...
#
#                                            description  \
# 0    만개한 <b>벚꽃</b>을 품에 안은 전농로 전역을 무대로 길거리공연, 버스킹, 거...
# 1    지난해 열린 보성<b>벚꽃</b>축제 모습./ 사진=보성군 전남 보성군이 오는 29...
# 2    따뜻한 햇볕을 받으며 <b>벚꽃</b>이 흩날리는 골프장에서의 라운드는 봄철에만 만...
# 3    3월 및 4월 중순까지는 일본의 <b>벚꽃</b>철로, 이 기간 일본을 찾는 여행객...
# 4    관내 12개 초·중학생 80명의 단원으로 구성돼 매년 세 차례의 정기연주회를 하고 ...
# ..                                                 ...
# 995  읍면동에서는 ▲봄맞이 대청결활동 및 봄꽃식재 추진 ▲장애인가구 주거환경개선 지원 ▲...
# 996  지난해 각종 축제에서 사용한 다회용기를 살펴보면 △청원생명축제 43만개 △무심천 <...
# 997  고창시티투어 노선은 △3월(운곡습지~선운산~고인돌박물관~고창읍성) △4월 5일(<b...
# 998  이번 행사는 무심천 <b>벚꽃</b> 개화 시기에 맞춰 공연, 전시, 연극, 강연,...
# 999  순천시(시장 노관규)는 지역 곳곳에 숨겨진 <b>벚꽃</b> 포토존을 배경으로 스냅...
#
#                              pubDate
# 0    Wed, 19 Mar 2025 18:16:00 +0900
# 1    Wed, 19 Mar 2025 18:12:00 +0900
# 2    Wed, 19 Mar 2025 18:10:00 +0900
# 3    Wed, 19 Mar 2025 18:06:00 +0900
# 4    Wed, 19 Mar 2025 18:04:00 +0900
# ..                               ...
# 995  Mon, 17 Mar 2025 16:12:00 +0900
# 996  Mon, 17 Mar 2025 16:10:00 +0900
# 997  Mon, 17 Mar 2025 16:09:00 +0900
# 998  Mon, 17 Mar 2025 16:04:00 +0900
# 999  Mon, 17 Mar 2025 16:02:00 +0900
#
# [1000 rows x 5 columns]
